# %%
import itertools
colours = ["R","G","Y","B","M"]
len([p for p in itertools.product(colours, repeat=4)])
# Out:
# 625

# %%
import itertools
colours = ["R","G","Y","B","M"]
[p for p in itertools.product(colours, repeat=3)]
# Out:
# [('R', 'R', 'R'),
#  ('R', 'R', 'G'),
#  ('R', 'R', 'Y'),
#  ('R', 'R', 'B'),
#  ('R', 'R', 'M'),
#  ('R', 'G', 'R'),
#  ('R', 'G', 'G'),
#  ('R', 'G', 'Y'),
#  ('R', 'G', 'B'),
#  ('R', 'G', 'M'),
#  ('R', 'Y', 'R'),
#  ('R', 'Y', 'G'),
#  ('R', 'Y', 'Y'),
#  ('R', 'Y', 'B'),
#  ('R', 'Y', 'M'),
#  ('R', 'B', 'R'),
#  ('R', 'B', 'G'),
#  ('R', 'B', 'Y'),
#  ('R', 'B', 'B'),
#  ('R', 'B', 'M'),
#  ('R', 'M', 'R'),
#  ('R', 'M', 'G'),
#  ('R', 'M', 'Y'),
#  ('R', 'M', 'B'),
#  ('R', 'M', 'M'),
#  ('G', 'R', 'R'),
#  ('G', 'R', 'G'),
#  ('G', 'R', 'Y'),
#  ('G', 'R', 'B'),
#  ('G', 'R', 'M'),
#  ('G', 'G', 'R'),
#  ('G', 'G', 'G'),
#  ('G', 'G', 'Y'),
#  ('G', 'G', 'B'),
#  ('G', 'G', 'M'),
#  ('G', 'Y', 'R'),
#  ('G', 'Y', 'G'),
#  ('G', 'Y', 'Y'),
#  ('G', 'Y', 'B'),
#  ('G', 'Y', 'M'),
#  ('G', 'B', 'R'),
#  ('G', 'B', 'G'),
#  ('G', 'B', 'Y'),
#  ('G', 'B', 'B'),
#  ('G', 'B', 'M'),
#  ('G', 'M', 'R'),
#  ('G', 'M', 'G'),
#  ('G', 'M', 'Y'),
#  ('G', 'M', 'B'),
#  ('G', 'M', 'M'),
# ...
