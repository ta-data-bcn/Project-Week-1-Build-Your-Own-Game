# %%
import random
district_list = ['POBLENOU', 'EIXAMPLE']

#Perfect solution to deliver
#First, let's define the districts to the two players:

while True:
    try:
        district_a = str(input("Player 1, in which district do you want to start? >>> ")).upper()
        if district_a in district_list:
            while True:
                district_b = str(input("Player 2, in which district do you want to start? >>> ")).upper()
                if district_b in district_list:
                    if district_a != district_b:
                        break
                    else:
                        print("This district is already taken. Try the other")
                else:
                    print(f"The district {district_b} doesn't exists. Start choosing teams again ")
                    continue
            break
        else:
            print(f"The district {district_a} doesn't exists. Please repeat again! ")
            continue
    except:
        pass
print("Let's start the first turn")

#Second, let's roll a dice:

def dice_1():
    dice1 = random.randint(1,6)
    return dice1
dice1=dice_1()

def dice_2():
    dice2 = random.randint(1,6)
    return dice2
dice2=dice_2()

if dice1 > dice2:
    print(dice1)
    print(dice2)
    print("Player1 won")
elif dice1 == dice2:
    print("Tie")
else:
    print(dice1)
    print(dice2)
    print("Player2 won")

#Last and the most important, let's join all together with the function (def main). Or not, because it works w/o def main as needed:

def main()
    renflvkd

while input("Do you want to play again?Yes/No ") if again == "Yes"
    vnfkldffn
    
if __name__ == "__main__"

# %%
import random
district_list = ['POBLENOU', 'EIXAMPLE']

#Perfect solution to deliver
#First, let's define the districts to the two players:

while True:
    try:
        district_a = str(input("Player 1, in which district do you want to start? >>> ")).upper()
        if district_a in district_list:
            while True:
                district_b = str(input("Player 2, in which district do you want to start? >>> ")).upper()
                if district_b in district_list:
                    if district_a != district_b:
                        break
                    else:
                        print("This district is already taken. Try the other")
                else:
                    print(f"The district {district_b} doesn't exists. Start choosing teams again ")
                    continue
            break
        else:
            print(f"The district {district_a} doesn't exists. Please repeat again! ")
            continue
    except:
        pass
print("Let's start the first turn")

#Second, let's roll a dice:

def dice_1():
    dice1 = random.randint(1,6)
    return dice1
dice1=dice_1()

def dice_2():
    dice2 = random.randint(1,6)
    return dice2
dice2=dice_2()

if dice1 > dice2:
    print(dice1)
    print(dice2)
    print("Player1 won")
elif dice1 == dice2:
    print("Tie")
else:
    print(dice1)
    print(dice2)
    print("Player2 won")
# Out:
# Player 1, in which district do you want to start? >>> poblenou
# Player 2, in which district do you want to start? >>> eixample
# Let's start the first turn
# 1
# 5
# Player2 won
