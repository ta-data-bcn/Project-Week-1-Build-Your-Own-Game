# %% [markdown]
# <font size="8"><font color = red>**Mastermind: Escape from Moria edition**<color></font>

# %% [markdown]
# Open the door before the Balrog reaches the fellowship!

# %%
#Mastermind colour scheme:
color_scheme = ["red", "orange", "green", "blue", "yellow", "white", "purple", "black"]

# %%
import random

# %%
#Mastermind's choice
ai_choices = random.sample(color_scheme, 4)
print(ai_choices)
# Out:
# ['red', 'orange', 'purple', 'black']

# %% [markdown]
# **Enter a color from the following color scheme: blue, red, orange, black, green, yellow, white, brown**

# %%
def concatenator(name1, name2):
    return name1 + ", " + name2

# %%
from functools import reduce

# %%
#Setting up the player's choice:

# %%
#Basic set up where we will check if the player choices match with the AI
name = input("Enter your name: ")

print("Hello "+ name + ". The Mastermind has chosen its' colors, now it's your turn:\n")


number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0

print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.\n")

player_choice1 = input("Enter color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.\n")
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors0 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors0 += 1
    elif player_choices[index] in ai_choices:
        close_wrong0 += 1
print("\n")        
print("You got ", wrong_colors0, "colors wrong!")
print("You have ", close_wrong0, "colors close but in the wrong position.")
print(correct_colors0, "correct!\n")

while player_choices != ai_choices:
    print("Try again " + name + "!\n")
    print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.")
    for index in range(len(player_choices)):
        if player_choices[index] not in ai_choices:
            wrong_colors1 += 1
        elif player_choices[index] == ai_choices[index]:
            correct_colors1 += 1
        elif player_choices[index] in ai_choices:
            close_wrong1 += 1        
    print("You got ", wrong_colors1, "colors wrong!")
    print("You have ", close_wrong1, "colors close but in the wrong position.")
    print(correct_colors1, "correct!")

    number_of_tries += 1
    if number_of_tries > 8:
        print("Game over.")
        break        
        
            
if player_choices == ai_choices:
    print("Congratulations " + name + "you've won!")
# Out:
# Enter your name: Erik
# Hello Erik. The Mastermind has chosen its' colors, now it's your turn:
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
#
# Enter color 1: blue
# Enter color 2: green
# Enter color 3: black
# Enter color 4: red
# You've chosen blue, green, black, red as your colors.
#
#
#
# You got  0 colors wrong!
# You have  3 colors close but in the wrong position.
# 1 correct!
#
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: green
# Enter color 2: blue
# Enter color 3: black
# Enter color 4: red
# You've chosen green, blue, black, red as your colors.
# You got  0 colors wrong!
# You have  4 colors close but in the wrong position.
# 0 correct!
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: blue
# Enter color 2: black
# Enter color 3: redf
# Please enter a valid color from the color scheme: red
# Enter color 4: green
# You've chosen blue, black, red, green as your colors.
# You got  0 colors wrong!
# You have  3 colors close but in the wrong position.
# 1 correct!
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: green
# Enter color 2: blue
# Enter color 3: red
# Enter color 4: black
# You've chosen green, blue, red, black as your colors.
# You got  0 colors wrong!
# You have  3 colors close but in the wrong position.
# 1 correct!
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: blue
# Enter color 2: black
# Enter color 3: red
# Enter color 4: green
# You've chosen blue, black, red, green as your colors.
# You got  0 colors wrong!
# You have  3 colors close but in the wrong position.
# 1 correct!
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: blue
# Enter color 2: red
# Enter color 3: black
# Enter color 4: green
# You've chosen blue, red, black, green as your colors.
# You got  0 colors wrong!
# You have  4 colors close but in the wrong position.
# 0 correct!
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
# Enter color 1: black
# Enter color 2: green
# Enter color 3: red
# Enter color 4: blue
# You've chosen black, green, red, blue as your colors.
# You got  0 colors wrong!
# You have  0 colors close but in the wrong position.
# 4 correct!
# Congratulations Erikyou've won!

# %%
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors1 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors1 += 1
    elif player_choices[index] in ai_choices:
        close_wrong1 += 1
# Out:
# 0 red
# 1 white
# 2 yellow
# 3 red

# %%
def choose_color_w_replacement(colors):
    colors_to_return = []
    while len(colors_to_return) < 4:
        a1 = random.choice(colors)
        if a1 not in colors_to_return:
                colors_to_return.append(a1)

# %%
print(ai_choices)
# Out:
# ['yellow', 'blue', 'black', 'white']

# %%
#Mastermind's choice:
ai_choice1 = random.choice(color_scheme)
ai_choice2 = random.choice(color_scheme)
ai_choice3 = random.choice(color_scheme)
ai_choice4 = random.choice(color_scheme)
ai_choices2 = [ai_choice1, ai_choice2, ai_choice3, ai_choice4]

# %%
#Basic set up where we will check if the player choices match with the AI
name = input("Enter your name: ")

print("Hello "+ name + ". The Mastermind has chosen its' colors, now it's your turn:\n")


number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0

print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.\n")

player_choice1 = input("Enter color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.\n")
for index,player_choice in enumerate(player_choices):
        if player_choice not in ai_choices:
            wrong_colors0 += 1
        elif player_choice == ai_choices[index]:
            correct_colors0 += 1
        elif player_choice in ai_choices:
            close_wrong0 += 1
print("\n")        
print("You got ", wrong_colors0, "colors wrong!")
print("You have ", close_wrong0, "colors close but in the wrong position.")
print(correct_colors0, "correct!\n")

while player_choices != ai_choices:
    print("Try again " + name + "!\n")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.")
    for index,player_choice in enumerate(player_choices):
        if player_choice not in ai_choices:
            wrong_colors1 += 1
        elif player_choice == ai_choices[index]:
            correct_colors1 += 1
        elif player_choice in ai_choices:
            close_wrong1 += 1        
    print("You got ", wrong_colors1, "colors wrong!")
    print("You have ", close_wrong1, "colors close but in the wrong position.")
    print(correct_colors1, "correct!")

    number_of_tries += 1
    if number_of_tries > 8:
        print("Game over.")
        break        
        
            
if player_choices == ai_choices:
    print("Congratulations " + name + "you've won!")

# %%
from IPython.display import Image, display

# %%
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

# %%
listOfImageNames0 = ['C:\\Users\\Erik\\ErikRepo\\project1\\Project-Week-1-Build-Your-Own-Game\\your-project\\moria.png']
for imageName in listOfImageNames0:
    display(Image(filename=imageName))
print("\n")

printmd("**After defeating Saruman, Gandalf is leading the fellowship of the ring to Mordor.\n**")
printmd("**Their travels have brought them to the mines of Moria, the only passage available for them to follow their path to Mordor.\n**")
printmd("**Once a propserous stronghold for dwarves, it has now been conquered, and the fellowship is ambushed by goblins.\n**")
printmd("**When the situation couldn't be any more desperate, Gandalf's worst fear comes true.\n The goblins scatter and go back to their hiding spot in fear of what's coming....\n**")
printmd("**-Frodo: What's going on, Gandalf!?\n**")
printmd("**-Gandalf: A creature is lurking in the shadows. A monster as evil as the depths of hell and as old as time itself, the Balrog of Morgoth... Run!\n**")



listOfImageNames1 = ['C:\\Users\\Erik\\ErikRepo\\project1\\Project-Week-1-Build-Your-Own-Game\\your-project\\Balrog.jpg']
listOfImageNames2 = ['C:\\Users\\Erik\\ErikRepo\\project1\\Project-Week-1-Build-Your-Own-Game\\your-project\\fly.jpg']
number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0
Gimly_voiceline1 = ("**-Gimly: I still don't know why you won't let me break it with my axe. \n Legloas: You couldn't break a ring\nyou think you can break a 10.000 year old door?\n Gimly: You're right, this ain't no Elf door, my cousins built this.\n**")
Gimly_voiceline2 = ("**-Gimly: Gandalf, why exactly couldn't those eagles fly the ring to Mordor?\n**")
Legolas_voiceline1 = ("**-Legolas: Gandalf, why don't you let me have a try? \n -Gimly: I'd rather die in these mountains than\nwatching an Elf open a dwarven door.\n**")
Legolas_voiceline2 = ("**-Legolas: My elf eyes see that we are absolutely f*cked if you don't open that door Gandalf!\n**")
Frodo_voiceline1 = ("**-Frodo: It's alright guys, I was never reaching Mordor anyways...\n**")
Aragorn_voiceline1 = ("**-Aragorn: I should've stayed in Rivendell with Arwen.\n**")
Boromir_voiceline1 = ("**-Boromir: Frodo, can I borrow that ring of yours for a couple minutes?\n**")
voicelines = [Gimly_voiceline1, Gimly_voiceline2, Legolas_voiceline1, Legolas_voiceline2, Frodo_voiceline1, Aragorn_voiceline1, Boromir_voiceline1]

print("As Gandalf and the rest of the fellowship are making their escape through the mines of Moria, only an old door stands between\nthe fellowship and the exit of the mountain. Gandalf inspects the door and discovers a hidden mechanism and 8 shiny gems of\ndifferent colors. Gandalf has seen this old spell before, if he pushes 4 gems out of the 8 in the correct order, the door will open.\nHelp Gandalf escape!")
print("Choose a gem color between " + reduce(concatenator, color_scheme) + " to get the correct combination before the \n Balrog reaches you!.\n")



player_choice1 = input("Enter gem color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter gem color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter gem color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter gem color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("Gandalf chooses " + reduce(concatenator, player_choices) + " as gem colors.")
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors0 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors0 += 1
    elif player_choices[index] in ai_choices:
        close_wrong0 += 1
print("\n")        
print("-Gandalf:", wrong_colors0, "colors wrong! We better get them right next time if we want to get out alive!")
print("-Gandalf:", close_wrong0, "colors are correct but they're in the wrong position, I can almost feel the Balrog's breath in my neck.")
print("-Gandalf:", correct_colors0 ,"correct! Why did the dwarves have to make it so hard!?")
print("The door remains closed, hurry up or the Balrog will reach the fellowship!")
for imageName in listOfImageNames1:
        display(Image(filename=imageName))

while player_choices != ai_choices:
    print("Choose one of these " + reduce(concatenator, color_scheme) + " gem colors to get the combination that will \ntake you out of the Balrog's reach!")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter gem color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter gem color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter gem color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter gem color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("-Aragorn: We have no time for silly games Gandalf, get us out of here! Pick a gem: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("Gandalf chooses " + reduce(concatenator, player_choices) + " as gem colors.")
    for index in range(len(player_choices)):
        if player_choices[index] not in ai_choices:
            wrong_colors1 += 1
        elif player_choices[index] == ai_choices[index]:
            correct_colors1 += 1
        elif player_choices[index] in ai_choices:
            close_wrong1 += 1        
    print("\n")
    print("-Gandalf:", wrong_colors0, "colors wrong! We better get them right next time if we want to get out alive!")
    print("-Gandalf:", close_wrong0, "colors are correct but they're in the wrong position, I can almost feel the Balrog's breath in my neck.")
    print("-Gandalf:", correct_colors0 ,"correct! Why did the dwarves have to make it so hard!?")
    print("\n-The door remains closed, hurry up or the Balrog will reach the fellowship.")
    for imageName in listOfImageNames1:
        display(Image(filename=imageName))
    printmd(random.choice(voicelines))

    number_of_tries += 1
    if number_of_tries > 8:
        printmd("*The Barlog has reached the fellowship before Gandalf could open the door, a fierce battle is ahead, the result will be tragic... The future of Middle Earth has come to an end.")
        break        
        
            
if player_choices == ai_choices:
    printmd("**-Frodo: Wait! Look!\n")
    printmd("**The door lights up as the fellowship stares in awe, it opens up to a bridge that will bring you yo your exit.\n**")
    printmd("**-Gandalf: Run, mortals! The Balrog is getting closer!\n**")
    printmd("**As the fellowship is crossing the bridge, the Balrog reaches our heroes. Gandalf, aware of the danger of the situation, turns back at the creature and conjures a spell:\n**")
    printmd("**-Gandalf: I am the servant of the Secret Fire, wielder of the Flame of Anor… The dark fire will not avail you! Flame of Udûn!\n**")
    printmd("**Gandalf destroys the bridge the Balrog, is standing on, leaving the creature behind. Suddenly, a fire whip strikes Gandalf, the Balrog drags him to the abyss of Moria... \n**")
    printmd("**As Gandalf falls with the Balrog, he whispers his last piece of advice for the fellowship:\n**")
    printmd("**-Gandalf: Fly, you fools!\n**")
    for imageName in listOfImageNames2:
        display(Image(filename=imageName))
# Out:
# **After defeating Saruman, Gandalf is leading the fellowship of the ring to Mordor.
# **
# **Their travels have brought them to the mines of Moria, the only passage available for them to follow their path to Mordor.
# **
# **Once a propserous stronghold for dwarves, it has now been conquered, and the fellowship is ambushed by goblins.
# **
# **When the situation couldn't be any more desperate, Gandalf's worst fear comes true.
#  The goblins scatter and go back to their hiding spot in fear of what's coming....
# **
# **-Frodo: What's going on, Gandalf!?
# **
# **-Gandalf: A creature is lurking in the shadows. A monster as evil as the depths of hell and as old as time itself, the Balrog of Morgoth... Run!
# **
# As Gandalf and the rest of the fellowship are making their escape through the mines of Moria, only an old door stands between
# the fellowship and the exit of the mountain. Gandalf inspects the door and discovers a hidden mechanism and 8 shiny gems of
# different colors. Gandalf has seen this old spell before, if he pushes 4 gems out of the 8 in the correct order, the door will open.
# Help Gandalf escape!
# Choose a gem color between red, orange, green, blue, yellow, white, purple, black to get the correct combination before the
#  Balrog reaches you!.
#
# Enter gem color 1: black
# Enter gem color 2: green
# Enter gem color 3: purple
# Enter gem color 4: orange
# Gandalf chooses black, green, purple, orange as gem colors.
#
#
# -Gandalf: 1 colors wrong! We better get them right next time if we want to get out alive!
# -Gandalf: 2 colors are correct but they're in the wrong position, I can almost feel the Balrog's breath in my neck.
# -Gandalf: 1 correct! Why did the dwarves have to make it so hard!?
# The door remains closed, hurry up or the Balrog will reach the fellowship!
# Choose one of these red, orange, green, blue, yellow, white, purple, black gem colors to get the combination that will
# take you out of the Balrog's reach!
# Enter gem color 1: blue
# Enter gem color 2: green
# Enter gem color 3: black
# Enter gem color 4: red
# Gandalf chooses blue, green, black, red as gem colors.
#
#
# -Gandalf: 1 colors wrong! We better get them right next time if we want to get out alive!
# -Gandalf: 2 colors are correct but they're in the wrong position, I can almost feel the Balrog's breath in my neck.
# -Gandalf: 1 correct! Why did the dwarves have to make it so hard!?
#
# -The door remains closed, hurry up or the Balrog will reach the fellowship.
# **-Gimly: Gandalf, exactly why couldn't those eagles of yours fly the ring to Mordor?
# **
# Choose one of these red, orange, green, blue, yellow, white, purple, black gem colors to get the combination that will
# take you out of the Balrog's reach!
