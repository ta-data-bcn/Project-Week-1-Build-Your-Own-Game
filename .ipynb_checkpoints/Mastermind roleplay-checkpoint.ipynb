# %% [markdown]
# <font size="8"><font color = blue>**Mastermind**<color></font>

# %% [markdown]
# Guess the colour the Mastermind has chosen to win.

# %%
#Mastermind colour scheme:
color_scheme = ["red", "orange", "green", "blue", "yellow", "white", "purple", "black"]

# %%
import random

# %%
#Mastermind's choice
ai_choices = random.sample(color_scheme, 4)
print(ai_choices)
# Out:
# ['blue', 'orange', 'red', 'yellow']

# %% [markdown]
# **Enter a color from the following color scheme: blue, red, orange, black, green, yellow, white, brown**

# %%
def concatenator(name1, name2):
    return name1 + ", " + name2

# %%
from functools import reduce

# %%
#Setting up the player's choice:

# %%
#Basic set up where we will check if the player choices match with the AI
name = input("Enter your name: ")

print("Hello "+ name + ". The Mastermind has chosen its' colors, now it's your turn:\n")


number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0

print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.\n")

player_choice1 = input("Enter color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.\n")
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors0 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors0 += 1
    elif player_choices[index] in ai_choices:
        close_wrong0 += 1
print("\n")        
print("You got ", wrong_colors0, "colors wrong!")
print("You have ", close_wrong0, "colors close but in the wrong position.")
print(correct_colors0, "correct!\n")

while player_choices != ai_choices:
    print("Try again " + name + "!\n")
    print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.")
    for index in range(len(player_choices)):
        if player_choices[index] not in ai_choices:
            wrong_colors1 += 1
        elif player_choices[index] == ai_choices[index]:
            correct_colors1 += 1
        elif player_choices[index] in ai_choices:
            close_wrong1 += 1        
    print("You got ", wrong_colors1, "colors wrong!")
    print("You have ", close_wrong1, "colors close but in the wrong position.")
    print(correct_colors1, "correct!")

    number_of_tries += 1
    if number_of_tries > 8:
        print("Game over.")
        break        
        
            
if player_choices == ai_choices:
    print("Congratulations " + name + "you've won!")
# Out:
# Enter your name: Erik
# Hello Erik. The Mastermind has chosen its' colors, now it's your turn:
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.
#
# Enter color 1: green
# Enter color 2: red
# Enter color 3: black
# Enter color 4: orange
# You've chosen green, red, black, orange as your colors.
#
#
#
# You got  1 colors wrong!
# You have  3 colors close but in the wrong position.
# 0 correct!
#
# Try again Erik!
#
# Please choose one of red, orange, green, blue, yellow, white, purple, black as your colors.

# %%
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors1 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors1 += 1
    elif player_choices[index] in ai_choices:
        close_wrong1 += 1
# Out:
# 0 red
# 1 white
# 2 yellow
# 3 red

# %%
def choose_color_w_replacement(colors):
    colors_to_return = []
    while len(colors_to_return) < 4:
        a1 = random.choice(colors)
        if a1 not in colors_to_return:
                colors_to_return.append(a1)

# %%
print(ai_choices)
# Out:
# ['yellow', 'blue', 'black', 'white']

# %%
#Mastermind's choice:
ai_choice1 = random.choice(color_scheme)
ai_choice2 = random.choice(color_scheme)
ai_choice3 = random.choice(color_scheme)
ai_choice4 = random.choice(color_scheme)
ai_choices2 = [ai_choice1, ai_choice2, ai_choice3, ai_choice4]

# %%
#Basic set up where we will check if the player choices match with the AI
name = input("Enter your name: ")

print("Hello "+ name + ". The Mastermind has chosen its' colors, now it's your turn:\n")


number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0

print("Please choose one of " + reduce(concatenator, color_scheme) + " as your colors.\n")

player_choice1 = input("Enter color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.\n")
for index,player_choice in enumerate(player_choices):
        if player_choice not in ai_choices:
            wrong_colors0 += 1
        elif player_choice == ai_choices[index]:
            correct_colors0 += 1
        elif player_choice in ai_choices:
            close_wrong0 += 1
print("\n")        
print("You got ", wrong_colors0, "colors wrong!")
print("You have ", close_wrong0, "colors close but in the wrong position.")
print(correct_colors0, "correct!\n")

while player_choices != ai_choices:
    print("Try again " + name + "!\n")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.")
    for index,player_choice in enumerate(player_choices):
        if player_choice not in ai_choices:
            wrong_colors1 += 1
        elif player_choice == ai_choices[index]:
            correct_colors1 += 1
        elif player_choice in ai_choices:
            close_wrong1 += 1        
    print("You got ", wrong_colors1, "colors wrong!")
    print("You have ", close_wrong1, "colors close but in the wrong position.")
    print(correct_colors1, "correct!")

    number_of_tries += 1
    if number_of_tries > 8:
        print("Game over.")
        break        
        
            
if player_choices == ai_choices:
    print("Congratulations " + name + "you've won!")

# %%
#Nerd shit
#Basic set up where we will check if the player choices match with the AI
name = input("Enter your name: ")

print("Hello "+ name + ". The Mastermind has chosen its' colors, now it's your turn:\n")


number_of_tries = 0
wrong_colors0 = 0
correct_colors0 = 0
close_wrong0 = 0
Gimly_voiceline1 = "Gimly: I still don't know why you won't let me break it with my axe. \n Legloas: You couldn't break a ring you think you can break a 10.000 year old door?\n Gimly: You're right, this ain't no Elf door, my cousins built this."
Gimly_voiceline2 = "Gimly: Gandalf, exactly why couldn't those eagles of yours fly the ring to Mordor?"
Legolas_voiceline1 = "Legolas: Gandalf, why don't you let me have a try? \n Gimly: I'd rather die in these mountains than watching an Elf open a dwarven door."
Legolas_voiceline2 = "Legolas: My elf eyes see that we are absolutely f*cked if you don't open that door Gandalf!"
Frodo_voiceline1 = "It's alright guys, I was never reaching Mordor anyways..."
Aragorn_voiceline1 = "I should've stayed in Rivendell with Arwen."
Boromir_voiceline1 = "Frodo can I borrow that ring of yours for a couple minutes?"
voicelines = [Gimly_voiceline1, Gimly_voiceline2, Legolas_voiceline1, Legolas_voiceline2, Frodo_voiceline1, Aragorn_voiceline1, Boromir_voiceline1]

print("Choose a gem color " + reduce(concatenator, color_scheme) + " to get the correct combination before the Balrog reaches you!.\n")

player_choice1 = input("Enter color 1: ")
while player_choice1 not in color_scheme:
    try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice2 = input("Enter color 2: ")
while player_choice2 not in color_scheme:    
    try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choice3 = input("Enter color 3: ")
while player_choice3 not in color_scheme:    
    try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
    except:            
            print("That's not a valid color, please try again.")
player_choice4 = input("Enter color 4: ")
while player_choice4 not in color_scheme:    
    try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
    except:
            print("That's not a valid color, please try again.")
player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.\n")
for index in range(len(player_choices)):
    if player_choices[index] not in ai_choices:
        wrong_colors0 += 1
    elif player_choices[index] == ai_choices[index]:
        correct_colors0 += 1
    elif player_choices[index] in ai_choices:
        close_wrong0 += 1
print("\n")        
print("Gandalf: ", wrong_colors0, "colors wrong!")
print("Gandalf: ", close_wrong0, "colors close but in the wrong position, I can almost feel the Balrog's breath in my neck.")
print("Gandalf: ", correct_colors0 ,"correct! Why did the dwarves have to make it so hard!?")
print("\n The door remains closed, hurry up or the Balrog will reach the fellowship.")

while player_choices != ai_choices:
    print("Wrong! Choose one of these " + reduce(concatenator, color_scheme) + " gem colors to get the combination that will take you out of the Balrog's reach!")
    wrong_colors1 = 0
    correct_colors1 = 0
    close_wrong1 = 0
    player_choice1 = input("Enter color 1: ")
    while player_choice1 not in color_scheme:
        try: 
            player_choice1 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice2 = input("Enter color 2: ")
    while player_choice2 not in color_scheme:    
        try: 
            player_choice2 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choice3 = input("Enter color 3: ")
    while player_choice3 not in color_scheme:    
        try: 
            player_choice3 = input("Please enter a valid color from the color scheme: ")
        except:            
            print("That's not a valid color, please try again.")
    player_choice4 = input("Enter color 4: ")
    while player_choice4 not in color_scheme:    
        try: 
            player_choice4 = input("Please enter a valid color from the color scheme: ")
        except:
            print("That's not a valid color, please try again.")
    player_choices = [player_choice1, player_choice2, player_choice3, player_choice4]
    print("You've chosen " + reduce(concatenator, player_choices) + " as your colors.")
    for index in range(len(player_choices)):
        if player_choices[index] not in ai_choices:
            wrong_colors1 += 1
        elif player_choices[index] == ai_choices[index]:
            correct_colors1 += 1
        elif player_choices[index] in ai_choices:
            close_wrong1 += 1        
    print("Gandalf: ", wrong_colors0, "colors wrong!")
    print("Gandalf: ", close_wrong0, "colors close but in the wrong position, I can almost feel the Balrog's breath in my neck.")
    print("Gandalf: ", correct_colors0 ,"correct! Why did the dwarves have to make it so hard!?")
    print("\n The door remains closed, hurry up or the Balrog will reach the fellowship.")
    print(random.choice(voicelines))

    number_of_tries += 1
    if number_of_tries > 8:
        print("Game over.")
        break        
        
            
if player_choices == ai_choices:
    print("Congratulations " + name + "you've won!")
# Out:
# Enter your name: Erik
# Hello Erik. The Mastermind has chosen its' colors, now it's your turn:
#
# Choose a gem color red, orange, green, blue, yellow, white, purple, black to get the correct combination before the Balrog reaches you!.
#
# Enter color 1: black
# Enter color 2: yellow
# Enter color 3: green
# Enter color 4: blue
# You've chosen black, yellow, green, blue as your colors.
#
#
#
# Gandalf:  2 colors wrong!
# Gandalf:  2 colors close but in the wrong position, I can almost feel the Balrog's breath in my neck.
# Gandalf:  0 correct! We're getting close.
#
#  The door remains closed, hurry up or the Balrog will reach the fellowship.
# Wrong! Choose one of these red, orange, green, blue, yellow, white, purple, black gem colors to get the combination that will take you out of the Balrog's reach!
